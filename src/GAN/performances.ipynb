# %%
import numpy as np
import glob
import imageio
import os
import matplotlib.pyplot as plt

# %%
dataset = []
path = os.path.dirname(os.getcwd()) + '/data/0.5928/*.npy'
for filename in glob.glob(path):
    with open(os.path.join(os.getcwd(), filename), 'rb') as f: 
        dataset.append(np.load(f).reshape(128,128,1))

# %%
fig = plt.figure(figsize=(4, 4))
plt.imshow(dataset[0], cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 127.5, 127.5, -0.5)

# %%
generated_dataset = []
path = os.path.dirname(os.getcwd()) + '/data/generated/*.npy'
for filename in glob.glob(path):
    with open(os.path.join(os.getcwd(), filename), 'rb') as f: 
        generated_dataset.append(np.load(f).reshape(128,128,1))

# %%
len(generated_dataset)
# Out:
# 20

# %%
fig = plt.figure(figsize=(4, 4))
plt.imshow(generated_dataset[-1] > 0, cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 127.5, 127.5, -0.5)

# %%
# Display a single image using the epoch number
def display_image(epoch_no):
  return PIL.Image.open('image_at_epoch_{:04d}.png'.format(epoch_no))

# %%
anim_file = 'dcgan.gif'

imageio.mimwrite(anim_file, generated_dataset)
# Out:
# Lossy conversion from float32 to uint8. Range [-0.9761813282966614, 0.9892582893371582]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [-0.9989389777183533, 0.9999721646308899]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [-0.9992309212684631, 0.9997792840003967]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [-0.9836024045944214, 0.9880733489990234]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [-0.9921243786811829, 0.9988332390785217]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float32 to uint8. Range [-0.999732255935669, 0.9999122023582458]. Convert image to uint8 prior to saving to suppress this warning.
# ...

# %%
import tensorflow_docs.vis.embed as embed
embed.embed_file(anim_file)
# Out:
# <img src="data:image/gif;base64,..."/>
